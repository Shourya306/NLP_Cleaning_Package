# %% [markdown]
# <a href="https://colab.research.google.com/github/Shourya306/Assignmet/blob/main/DSA_Daily_Pratice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Set Matrix Zero**
#
# Given a matrix, A of size M x N of 0s and 1s. If an element is 0, set its entire row and column to 0.
# Note: This will be evaluated on the extra memory used. Try to minimize the space and time complexity.
#
# Input Format:
#
# The first and the only argument of input contains a 2-d integer matrix, A, of size M x N.
# Output Format:
#
# Return a 2-d matrix that satisfies the given conditions.
#
# Examples:
#
# Input 1:
#     [   [1, 0, 1],
#         [1, 1, 1],
#         [1, 1, 1]   ]
#
#
# Output 1:
#     [   [0, 0, 0],
#         [1, 0, 1],
#         [1, 0, 1]   ]
#
#
#
# Input 2:
#     [   [1, 0, 1],
#         [1, 1, 1],
#         [1, 0, 1]   ]
#
#
#
# Output 2:
#     [   [0, 0, 0],
#         [1, 0, 1],
#         [0, 0, 0]   ]

# %%
def set_zeros(A):
  row = set()
  col = set()
  for i in range(len(A)):
    for j in range(len(A[0])):
      if A[i][j] == 0:
        row.add(i)
        col.add(j)
  for i in row:
    for j in range(len(A[0])):
      A[i][j] = 0
  for j in col:
    for i in range(len(A)):
      A[i][j] = 0
  return A

# %%
set_zeros([[1, 0, 1],[1, 1, 1],[1, 0, 1]])
# Out:
# [[0, 0, 0], [1, 0, 1], [0, 0, 0]]
